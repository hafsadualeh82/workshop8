# %%
from github import Github

# paste your token here
token = "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"

g = Github(token)

# your repo
repo = g.get_repo("hafsadualeh82/workshop8")

print("Repository:", repo.full_name)
print("Stargazers:", repo.stargazers_count)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1500\1762673794.py:6: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(token)
# Repository: hafsadualeh82/workshop8
# Stargazers: 0
